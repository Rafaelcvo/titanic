# %% [markdown]
# Interagindo com apis web

# %%
import requests
import pandas as pd

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()

# %%
data[0]['title']
# Out:
# 'Issue with to_clipboard(excel=True) with negative floats'

# %%
issues = pd.DataFrame(data, columns=['number', 'title', 'labels', 'state'])
issues
# Out:
#     number                                              title  \
# 0    27680  Issue with to_clipboard(excel=True) with negat...
# 1    27679             to_parquet swallows NoCredentialsError
# 2    27678  Series.append verify_integrity should fail on ...
# 3    27677  BUG: fixes formatted value error for missing s...
# 4    27676  read_excel: sheet_name of non-existent sheet d...
# 5    27674  Handle construction of string ExtensionArray f...
# 6    27673  String-based ExtensionArrays force cast to num...
# 7    27672  dataframe.fillna with df fails in a specific case
# 8    27671             Pandas Series Resampling Produces NaNs
# 9    27670  `value_counts` does not respect ordered catego...
# 10   27667           BUG: fix nested meta path bug (GH 27220)
# 11   27666                 Cheat sheet link is broken in docs
# 12   27665                 BUG: Allow plotting boolean values
# 13   27664  issue#27482 - added a check for if obj is inst...
# 14   27663  BUG: pd.crosstab not working when margin and n...
# 15   27662  DOC: add anonymizeIp for Google analytics in docs
# 16   27660         Pandas replace does not work with booleans
# 17   27656  API: many custom errors / warnings are not exp...
# 18   27655                   pandas.read_csv() encoding issue
# 19   27654  BUG: pandas.cut should optionally allow overla...
# 20   27653                       BUG: Fix dir(interval_index)
# 21   27652  API: Meta-issue for making consistent API's to...
# 22   27650  issue #27642 - timedelta merge asof with toler...
# 23   27649                             Add a "scope" document
# 24   27646        TYPING: add some type hints to core.generic
# 25   27645  BUG: Add mapping for pyqt for successful packa...
# 26   27642  merge_asof(): cannot use tolerance flag when t...
# 27   27639                     Max recursion limit on pd.eval
# 28   27637        Add comment char parameter to to_csv method
# 29   27636  Operators between DataFrame and Series fail on...
#
#                                                labels state
# 0                                                  []  open
# 1                                                  []  open
# 2                                                  []  open
# 3                                                  []  open
# 4                                                  []  open
# 5                                                  []  open
# 6                                                  []  open
# 7                                                  []  open
# 8   [{'id': 307649777, 'node_id': 'MDU6TGFiZWwzMDc...  open
# 9                                                  []  open
# 10                                                 []  open
# 11                                                 []  open
# 12                                                 []  open
# 13  [{'id': 2822342, 'node_id': 'MDU6TGFiZWwyODIyM...  open
# 14  [{'id': 13098779, 'node_id': 'MDU6TGFiZWwxMzA5...  open
# 15  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 16                                                 []  open
# 17  [{'id': 35818298, 'node_id': 'MDU6TGFiZWwzNTgx...  open
# 18  [{'id': 47229171, 'node_id': 'MDU6TGFiZWw0NzIy...  open
# 19  [{'id': 35818298, 'node_id': 'MDU6TGFiZWwzNTgx...  open
# 20  [{'id': 32815646, 'node_id': 'MDU6TGFiZWwzMjgx...  open
# 21                                                 []  open
# 22  [{'id': 13098779, 'node_id': 'MDU6TGFiZWwxMzA5...  open
# 23  [{'id': 6185226, 'node_id': 'MDU6TGFiZWw2MTg1M...  open
# 24  [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMj...  open
# 25  [{'id': 527603109, 'node_id': 'MDU6TGFiZWw1Mjc...  open
# 26  [{'id': 13098779, 'node_id': 'MDU6TGFiZWwxMzA5...  open
# 27                                                 []  open
# 28  [{'id': 47229171, 'node_id': 'MDU6TGFiZWw0NzIy...  open
# 29  [{'id': 47223669, 'node_id': 'MDU6TGFiZWw0NzIy...  open
