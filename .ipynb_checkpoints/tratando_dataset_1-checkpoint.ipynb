# %% [markdown]
# |Variable|Variável     |Definição	                              |Chave                                         |
# |--------|-------------|------------------------------------------|----------------------------------------------|
# |survival|sobrevivência|Sobrevivência                             |0 = Não, 1 = Sim                              |
# |pclass  |pclass	   |Classe de ingresso                        |1 = 1º, 2 = 2º, 3 = 3º                        |
# |ex      |sexo         |Sexo                                      |                                              |
# |Age     |Idade em anos| -                                        |                                              |
# |sibsp   |sibsp        |Nº de irmãos / cônjuges a bordo do Titanic|	                                             |
# |parch   |pergaminho   |Nº de pais / filhos a bordo do Titanic    |                                              |
# |ticket  |bilhete      |Número do bilhete	                      |                                              |
# |fare    |tarifa       |Tarifa de passageiro                      |	                                             |
# |cabin   |cabine       |Número da cabine	                      |                                              |
# |embarked|embarcou     |Porto de embarcação                       |C = Cherbourg, Q = Queenstown, S = Southampton|

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# %%
train = pd.read_csv('dataset/train.csv')
test = pd.read_csv('dataset/test.csv')

# %%
# Convertendo em binario
# transf = {"male": 0, "female": 1}

# train['Sex'] = train['Sex'].map(transf)
# test['Sex'] = test['Sex'].map(transf)

# %%
# Convertendo ticket para numeric
train['Ticket'] = train['Ticket'].str.replace(r'\D', '')
train['Ticket'] = pd.to_numeric(train['Ticket'])

# %%
# Todos os tickets iguais
lista= train['Ticket']
count = Counter(lista)

repetidos = [item for item, quant in count.items() if quant > 1]
df_ticket = train.set_index('Ticket')
df_ticket = df_ticket.loc[repetidos]

# # idade igual a nan
# idx = df_ticket[df_ticket['Age'].isnull()].index
# idx = idx.unique()
# df_fm = df_ticket.loc[idx]

# %%
# Separando duplas
# uni = df_ticket[(df_ticket['Parch'] == 0) & (df_ticket['SibSp'] == 1)].index
# df_ticket['Dupla'] = 0
# df_ticket['Dupla'].loc[uni] = 1

# %%
uni = df_ticket.index
count = Counter(uni)
dupla = [item for item, quant in count.items() if quant == 2]

# %%
df = df_ticket.rename(columns={'SibSp':'ir/conj', 'Parch':'pais/filhos'})

# %%
df[df['pais/filhos']>2]
# Out:
#            PassengerId  Survived  Pclass  \
# Ticket
# 349909.0           568         0       3
# 347082.0            14         0       3
# 347082.0           611         0       3
# 382652.0           886         0       3
# 347077.0            26         1       3
# 19950.0            439         0       1
# 3101295.0          639         0       3
# 2144.0             679         0       3
# 347088.0           168         0       3
# 347088.0           361         0       3
# 6608.0              87         0       3
# 6608.0             737         0       3
# 29106.0            438         1       2
# 2666.0             859         1       3
#
#                                                         Name     Sex   Age  \
# Ticket
# 349909.0         Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0
# 347082.0                         Andersson, Mr. Anders Johan    male  39.0
# 347082.0   Andersson, Mrs. Anders Johan (Alfrida Konstant...  female  39.0
# 382652.0                Rice, Mrs. William (Margaret Norton)  female  39.0
# 347077.0   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0
# 19950.0                                    Fortune, Mr. Mark    male  64.0
# 3101295.0             Panula, Mrs. Juha (Maria Emilia Ojala)  female  41.0
# 2144.0               Goodwin, Mrs. Frederick (Augusta Tyler)  female  43.0
# 347088.0     Skoog, Mrs. William (Anna Bernhardina Karlsson)  female  45.0
# 347088.0                                  Skoog, Mr. Wilhelm    male  40.0
# 6608.0                                Ford, Mr. William Neal    male  16.0
# 6608.0               Ford, Mrs. Edward (Margaret Ann Watson)  female  48.0
# 29106.0                Richards, Mrs. Sidney (Emily Hocking)  female  24.0
# 2666.0                 Baclini, Mrs. Solomon (Latifa Qurban)  female  24.0
#
#            ir/conj  pais/filhos      Fare        Cabin Embarked
# Ticket
# 349909.0         0            4   21.0750          NaN        S
# 347082.0         1            5   31.2750          NaN        S
# 347082.0         1            5   31.2750          NaN        S
# 382652.0         0            5   29.1250          NaN        Q
# 347077.0         1            5   31.3875          NaN        S
# 19950.0          1            4  263.0000  C23 C25 C27        S
# 3101295.0        0            5   39.6875          NaN        S
# 2144.0           1            6   46.9000          NaN        S
# 347088.0         1            4   27.9000          NaN        S
# 347088.0         1            4   27.9000          NaN        S
# 6608.0           1            3   34.3750          NaN        S
# 6608.0           1            3   34.3750          NaN        S
# 29106.0          2            3   18.7500          NaN        S
# 2666.0           0            3   19.2583          NaN        C
